# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1.1.Install Pycaret

# %%
# !conda install -c conda-forge pycaret -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/g7/anaconda3
#
#   added / updated specs:
#     - pycaret
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  conda-forge
#     catalogue-1.0.0            |   py38h578d9bd_3          13 KB  conda-forge
#     catboost-1.0.3             |   py38h578d9bd_1        60.1 MB  conda-forge
#     chart-studio-1.1.0         |     pyh9f0ad1d_0          51 KB  conda-forge
#     colorlover-0.3.0           |             py_0          12 KB  conda-forge
#     configparser-5.1.0         |     pyhd8ed1ab_0          21 KB  conda-forge
#     confuse-1.6.0              |     pyhd8ed1ab_0          22 KB  conda-forge
#     cufflinks-py-0.17.3        |             py_0           4 KB  conda-forge
#     cymem-2.0.5                |   py38h709712a_2          42 KB  conda-forge
#     cython-blis-0.7.4          |   py38h5c078b8_0         3.9 MB  conda-forge
#     docker-pycreds-0.4.0       |             py_0          11 KB  conda-forge
#     funcy-1.16                 |     pyhd8ed1ab_0          30 KB  conda-forge
#     gensim-4.0.1               |   py38h709712a_0        22.5 MB  conda-forge
#     gitpython-3.1.24           |     pyhd8ed1ab_0         122 KB  conda-forge
#     gorilla-0.4.0              |     pyhd8ed1ab_0          13 KB  conda-forge
#     gunicorn-20.1.0            |   py38h578d9bd_1         119 KB  conda-forge
#     htmlmin-0.1.12             |             py_1          21 KB  conda-forge
#     imbalanced-learn-0.8.1     |     pyhd8ed1ab_0         110 KB  conda-forge
#     importlib_resources-5.4.0  |     pyhd8ed1ab_0          21 KB  conda-forge
#     libprotobuf-3.17.2         |       h780b84a_1         2.5 MB  conda-forge
#     libxgboost-1.4.0           |       h9c3ff4c_0         3.3 MB  conda-forge
#     mako-1.1.6                 |     pyhd8ed1ab_0          58 KB  conda-forge
#     missingno-0.4.2            |             py_1          12 KB  conda-forge
#     mlflow-1.7.0               |           py38_0         3.4 MB  conda-forge
#     mlxtend-0.19.0             |     pyhd8ed1ab_0         1.2 MB  conda-forge
#     murmurhash-1.0.5           |   py38h709712a_0          26 KB  conda-forge
#     pandas-profiling-2.12.0    |     pyhd8ed1ab_0         157 KB  conda-forge
#     plac-0.9.6                 |             py_1          18 KB  conda-forge
#     plotly-5.4.0               |     pyhd8ed1ab_0         6.9 MB  conda-forge
#     py-xgboost-1.4.0           |   py38h578d9bd_0         142 KB  conda-forge
#     pycaret-2.2.3              |     pyhd3deb0d_0         166 KB  conda-forge
#     pyldavis-3.3.1             |     pyhd8ed1ab_0         114 KB  conda-forge
#     pynndescent-0.5.5          |     pyh6c4a22f_0          44 KB  conda-forge
#     pyod-0.9.5                 |     pyhd8ed1ab_0          80 KB  conda-forge
#     querystring_parser-1.2.4   |             py_0          10 KB  conda-forge
#     seaborn-base-0.11.2        |     pyhd8ed1ab_0         223 KB  conda-forge
#     smmap-3.0.5                |     pyh44b312d_0          22 KB  conda-forge
#     spacy-2.3.7                |   py38hfc89cab_0         8.9 MB  conda-forge
#     sqlparse-0.4.2             |     pyhd8ed1ab_0          34 KB  conda-forge
#     tangled-up-in-unicode-0.2.0|     pyhd8ed1ab_0         2.9 MB  conda-forge
#     textblob-0.15.3            |             py_0         595 KB  conda-forge
#     thinc-7.4.5                |   py38hc10631b_2         1.0 MB  conda-forge
#     umap-learn-0.5.2           |   py38h578d9bd_0         131 KB  conda-forge
#     websocket-client-1.2.1     |   py38h578d9bd_0          71 KB  conda-forge
#     yellowbrick-1.3.post1      |     pyhd8ed1ab_1         154 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       119.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/linux-64::_py-xgboost-mutex-2.0-cpu_0
#   alembic            conda-forge/noarch::alembic-1.7.5-pyhd8ed1ab_0
#   catalogue          conda-forge/linux-64::catalogue-1.0.0-py38h578d9bd_3
#   catboost           conda-forge/linux-64::catboost-1.0.3-py38h578d9bd_1
#   chart-studio       conda-forge/noarch::chart-studio-1.1.0-pyh9f0ad1d_0
#   colorlover         conda-forge/noarch::colorlover-0.3.0-py_0
#   configparser       conda-forge/noarch::configparser-5.1.0-pyhd8ed1ab_0
#   confuse            conda-forge/noarch::confuse-1.6.0-pyhd8ed1ab_0
#   cufflinks-py       conda-forge/noarch::cufflinks-py-0.17.3-py_0
#   cymem              conda-forge/linux-64::cymem-2.0.5-py38h709712a_2
#   cython-blis        conda-forge/linux-64::cython-blis-0.7.4-py38h5c078b8_0
#   databricks-cli     conda-forge/noarch::databricks-cli-0.12.1-pyhd8ed1ab_0
#   datefinder         conda-forge/noarch::datefinder-0.7.1-pyh9f0ad1d_0
#   docker-py          conda-forge/linux-64::docker-py-5.0.3-py38h578d9bd_0
#   docker-pycreds     conda-forge/noarch::docker-pycreds-0.4.0-py_0
#   funcy              conda-forge/noarch::funcy-1.16-pyhd8ed1ab_0
#   gensim             conda-forge/linux-64::gensim-4.0.1-py38h709712a_0
#   gitdb              conda-forge/noarch::gitdb-4.0.9-pyhd8ed1ab_0
#   gitpython          conda-forge/noarch::gitpython-3.1.24-pyhd8ed1ab_0
#   gorilla            conda-forge/noarch::gorilla-0.4.0-pyhd8ed1ab_0
#   gunicorn           conda-forge/linux-64::gunicorn-20.1.0-py38h578d9bd_1
#   htmlmin            conda-forge/noarch::htmlmin-0.1.12-py_1
#   imagehash          conda-forge/noarch::imagehash-4.2.1-pyhd8ed1ab_0
#   imbalanced-learn   conda-forge/noarch::imbalanced-learn-0.8.1-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-5.4.0-pyhd8ed1ab_0
#   kmodes             conda-forge/noarch::kmodes-0.11.0-pyh44b312d_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.17.2-h780b84a_1
#   libxgboost         conda-forge/linux-64::libxgboost-1.4.0-h9c3ff4c_0
#   lightgbm           conda-forge/linux-64::lightgbm-3.2.1-py38h709712a_0
#   mako               conda-forge/noarch::mako-1.1.6-pyhd8ed1ab_0
#   missingno          conda-forge/noarch::missingno-0.4.2-py_1
#   mlflow             conda-forge/linux-64::mlflow-1.7.0-py38_0
#   mlxtend            conda-forge/noarch::mlxtend-0.19.0-pyhd8ed1ab_0
#   murmurhash         conda-forge/linux-64::murmurhash-1.0.5-py38h709712a_0
#   pandas-profiling   conda-forge/noarch::pandas-profiling-2.12.0-pyhd8ed1ab_0
#   plac               conda-forge/noarch::plac-0.9.6-py_1
#   plotly             conda-forge/noarch::plotly-5.4.0-pyhd8ed1ab_0
#   preshed            conda-forge/linux-64::preshed-3.0.5-py38h709712a_1
#   prometheus_flask_~ conda-forge/noarch::prometheus_flask_exporter-0.18.5-pyhd8ed1ab_0
#   protobuf           conda-forge/linux-64::protobuf-3.17.2-py38h709712a_0
#   py-xgboost         conda-forge/linux-64::py-xgboost-1.4.0-py38h578d9bd_0
#   pycaret            conda-forge/noarch::pycaret-2.2.3-pyhd3deb0d_0
#   pyldavis           conda-forge/noarch::pyldavis-3.3.1-pyhd8ed1ab_0
#   pynndescent        conda-forge/noarch::pynndescent-0.5.5-pyh6c4a22f_0
#   pyod               conda-forge/noarch::pyod-0.9.5-pyhd8ed1ab_0
#   python-cufflinks   conda-forge/noarch::python-cufflinks-0.17.3-py_0
#   querystring_parser conda-forge/noarch::querystring_parser-1.2.4-py_0
#   retrying           conda-forge/noarch::retrying-1.3.3-py_2
#   seaborn-base       conda-forge/noarch::seaborn-base-0.11.2-pyhd8ed1ab_0
#   simplejson         conda-forge/linux-64::simplejson-3.17.3-py38h497a2fe_0
#   smart_open         conda-forge/noarch::smart_open-5.2.1-pyhd8ed1ab_0
#   smmap              conda-forge/noarch::smmap-3.0.5-pyh44b312d_0
#   spacy              conda-forge/linux-64::spacy-2.3.7-py38hfc89cab_0
#   sqlparse           conda-forge/noarch::sqlparse-0.4.2-pyhd8ed1ab_0
#   srsly              conda-forge/linux-64::srsly-1.0.5-py38h709712a_0
#   tangled-up-in-uni~ conda-forge/noarch::tangled-up-in-unicode-0.2.0-pyhd8ed1ab_0
#   tenacity           conda-forge/noarch::tenacity-8.0.1-pyhd8ed1ab_0
#   textblob           conda-forge/noarch::textblob-0.15.3-py_0
#   thinc              conda-forge/linux-64::thinc-7.4.5-py38hc10631b_2
#   umap-learn         conda-forge/linux-64::umap-learn-0.5.2-py38h578d9bd_0
#   visions            conda-forge/noarch::visions-0.6.0-pyh9f0ad1d_0
#   wasabi             conda-forge/noarch::wasabi-0.8.2-pyh44b312d_0
#   websocket-client   conda-forge/linux-64::websocket-client-1.2.1-py38h578d9bd_0
#   wordcloud          conda-forge/linux-64::wordcloud-1.8.1-py38h497a2fe_1
#   xgboost            conda-forge/linux-64::xgboost-1.4.0-py38h578d9bd_0
#   yellowbrick        conda-forge/noarch::yellowbrick-1.3.post1-pyhd8ed1ab_1
#
# The following packages will be UPDATED:
#
#   conda                               4.10.3-py38h578d9bd_3 --> 4.10.3-py38h578d9bd_4
#
#
#
# Downloading and Extracting Packages
# cufflinks-py-0.17.3  | 4 KB      | ##################################### | 100%
# catalogue-1.0.0      | 13 KB     | ##################################### | 100%
# plotly-5.4.0         | 6.9 MB    | ##################################### | 100%
# pynndescent-0.5.5    | 44 KB     | ##################################### | 100%
# confuse-1.6.0        | 22 KB     | ##################################### | 100%
# mlxtend-0.19.0       | 1.2 MB    | ##################################### | 100%
# textblob-0.15.3      | 595 KB    | ##################################### | 100%
# _py-xgboost-mutex-2. | 8 KB      | ##################################### | 100%
# websocket-client-1.2 | 71 KB     | ##################################### | 100%
# seaborn-base-0.11.2  | 223 KB    | ##################################### | 100%
# libprotobuf-3.17.2   | 2.5 MB    | ##################################### | 100%
# chart-studio-1.1.0   | 51 KB     | ##################################### | 100%
# funcy-1.16           | 30 KB     | ##################################### | 100%
# catboost-1.0.3       | 60.1 MB   | ##################################### | 100%
# yellowbrick-1.3.post | 154 KB    | ##################################### | 100%
# libxgboost-1.4.0     | 3.3 MB    | ##################################### | 100%
# querystring_parser-1 | 10 KB     | ##################################### | 100%
# pycaret-2.2.3        | 166 KB    | ##################################### | 100%
# py-xgboost-1.4.0     | 142 KB    | ##################################### | 100%
# plac-0.9.6           | 18 KB     | ##################################### | 100%
# gitpython-3.1.24     | 122 KB    | ##################################### | 100%
# mako-1.1.6           | 58 KB     | ##################################### | 100%
# missingno-0.4.2      | 12 KB     | ##################################### | 100%
# murmurhash-1.0.5     | 26 KB     | ##################################### | 100%
# configparser-5.1.0   | 21 KB     | ##################################### | 100%
# cython-blis-0.7.4    | 3.9 MB    | ##################################### | 100%
# thinc-7.4.5          | 1.0 MB    | ##################################### | 100%
# tangled-up-in-unicod | 2.9 MB    | ##################################### | 100%
# smmap-3.0.5          | 22 KB     | ##################################### | 100%
# gunicorn-20.1.0      | 119 KB    | ##################################### | 100%
# colorlover-0.3.0     | 12 KB     | ##################################### | 100%
# docker-pycreds-0.4.0 | 11 KB     | ##################################### | 100%
# cymem-2.0.5          | 42 KB     | ##################################### | 100%
# importlib_resources- | 21 KB     | ##################################### | 100%
# imbalanced-learn-0.8 | 110 KB    | ##################################### | 100%
# spacy-2.3.7          | 8.9 MB    | ##################################### | 100%
# htmlmin-0.1.12       | 21 KB     | ##################################### | 100%
# gensim-4.0.1         | 22.5 MB   | ##################################### | 100%
# pandas-profiling-2.1 | 157 KB    | ##################################### | 100%
# mlflow-1.7.0         | 3.4 MB    | ##################################### | 100%
# pyldavis-3.3.1       | 114 KB    | ##################################### | 100%
# umap-learn-0.5.2     | 131 KB    | ##################################### | 100%
# gorilla-0.4.0        | 13 KB     | ##################################### | 100%
# pyod-0.9.5           | 80 KB     | ##################################### | 100%
# sqlparse-0.4.2       | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %% [markdown]
# ## 1.2 Import Data

# %%
import pandas as pd
df = pd.read_csv('churn_data.csv', index_col='customerID')
df
# Out:
#             tenure PhoneService        Contract              PaymentMethod  \
# customerID
# 7590-VHVEG       1           No  Month-to-month           Electronic check
# 5575-GNVDE      34          Yes        One year               Mailed check
# 3668-QPYBK       2          Yes  Month-to-month               Mailed check
# 7795-CFOCW      45           No        One year  Bank transfer (automatic)
# 9237-HQITU       2          Yes  Month-to-month           Electronic check
# ...            ...          ...             ...                        ...
# 6840-RESVB      24          Yes        One year               Mailed check
# 2234-XADUH      72          Yes        One year    Credit card (automatic)
# 4801-JZAZL      11           No  Month-to-month           Electronic check
# 8361-LTMKD       4          Yes  Month-to-month               Mailed check
# 3186-AJIEK      66          Yes        Two year  Bank transfer (automatic)
#
#             MonthlyCharges  TotalCharges Churn
# customerID
# 7590-VHVEG           29.85         29.85    No
# 5575-GNVDE           56.95       1889.50    No
# 3668-QPYBK           53.85        108.15   Yes
# 7795-CFOCW           42.30       1840.75    No
# 9237-HQITU           70.70        151.65   Yes
# ...                    ...           ...   ...
# 6840-RESVB           84.80       1990.50    No
# 2234-XADUH          103.20       7362.90    No
# 4801-JZAZL           29.60        346.45    No
# 8361-LTMKD           74.40        306.60   Yes
# 3186-AJIEK          105.65       6844.50    No
#
# [7043 rows x 7 columns]

# %% [markdown]
# # 2. AutoML

# %% [markdown]
# Original automl work in JupyterLab had errors.  When switching to Notebook the problem seemed to resolve. Experimentation with 2 datasets follow but only the last experiment is shown in the notebook.

# %%
#automl = setup(df, target='Churn', fold_shuffle=True)
automl = setup(df, target='Churn')
# Out:
# <style type="text/css">
# #T_77e4e_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_77e4e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77e4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77e4e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_77e4e_row0_col1" class="data row0 col1" >1257</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77e4e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_77e4e_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77e4e_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_77e4e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77e4e_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_77e4e_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77e4e_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_77e4e_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_77e4e_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_77e4e_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77e4e_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_77e4e_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77e4e_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_77e4e_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77e4e_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_77e4e_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_77e4e_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_77e4e_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_77e4e_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_77e4e_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_77e4e_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_77e4e_row11_col1" class="data row11 col1" >(4930, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_77e4e_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_77e4e_row12_col1" class="data row12 col1" >(2113, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_77e4e_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_77e4e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_77e4e_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_77e4e_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_77e4e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_77e4e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_77e4e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_77e4e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_77e4e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_77e4e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_77e4e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_77e4e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_77e4e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_77e4e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_77e4e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_77e4e_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_77e4e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_77e4e_row21_col1" class="data row21 col1" >4967</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_77e4e_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_77e4e_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_77e4e_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_77e4e_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_77e4e_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_77e4e_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_77e4e_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_77e4e_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_77e4e_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_77e4e_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_77e4e_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_77e4e_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_77e4e_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_77e4e_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_77e4e_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_77e4e_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_77e4e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_77e4e_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_77e4e_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_46c93_ th {
#   text-align: left;
# }
# #T_46c93_row0_col0, #T_46c93_row0_col2, #T_46c93_row0_col3, #T_46c93_row0_col4, #T_46c93_row0_col5, #T_46c93_row1_col0, #T_46c93_row1_col1, #T_46c93_row1_col3, #T_46c93_row1_col5, #T_46c93_row1_col6, #T_46c93_row1_col7, #T_46c93_row2_col0, #T_46c93_row2_col1, #T_46c93_row2_col2, #T_46c93_row2_col3, #T_46c93_row2_col4, #T_46c93_row2_col5, #T_46c93_row2_col6, #T_46c93_row2_col7, #T_46c93_row3_col0, #T_46c93_row3_col1, #T_46c93_row3_col2, #T_46c93_row3_col3, #T_46c93_row3_col4, #T_46c93_row3_col5, #T_46c93_row3_col6, #T_46c93_row3_col7, #T_46c93_row4_col0, #T_46c93_row4_col1, #T_46c93_row4_col2, #T_46c93_row4_col3, #T_46c93_row4_col4, #T_46c93_row4_col5, #T_46c93_row4_col6, #T_46c93_row4_col7, #T_46c93_row5_col0, #T_46c93_row5_col1, #T_46c93_row5_col2, #T_46c93_row5_col3, #T_46c93_row5_col4, #T_46c93_row5_col5, #T_46c93_row5_col6, #T_46c93_row5_col7, #T_46c93_row6_col0, #T_46c93_row6_col1, #T_46c93_row6_col2, #T_46c93_row6_col3, #T_46c93_row6_col4, #T_46c93_row6_col5, #T_46c93_row6_col6, #T_46c93_row6_col7, #T_46c93_row7_col0, #T_46c93_row7_col1, #T_46c93_row7_col2, #T_46c93_row7_col3, #T_46c93_row7_col4, #T_46c93_row7_col5, #T_46c93_row7_col6, #T_46c93_row7_col7, #T_46c93_row8_col0, #T_46c93_row8_col1, #T_46c93_row8_col2, #T_46c93_row8_col3, #T_46c93_row8_col4, #T_46c93_row8_col5, #T_46c93_row8_col6, #T_46c93_row8_col7, #T_46c93_row9_col0, #T_46c93_row9_col1, #T_46c93_row9_col2, #T_46c93_row9_col3, #T_46c93_row9_col4, #T_46c93_row9_col5, #T_46c93_row9_col6, #T_46c93_row9_col7, #T_46c93_row10_col0, #T_46c93_row10_col1, #T_46c93_row10_col2, #T_46c93_row10_col3, #T_46c93_row10_col4, #T_46c93_row10_col5, #T_46c93_row10_col6, #T_46c93_row10_col7, #T_46c93_row11_col0, #T_46c93_row11_col1, #T_46c93_row11_col2, #T_46c93_row11_col3, #T_46c93_row11_col4, #T_46c93_row11_col5, #T_46c93_row11_col6, #T_46c93_row11_col7, #T_46c93_row12_col0, #T_46c93_row12_col1, #T_46c93_row12_col2, #T_46c93_row12_col4, #T_46c93_row12_col6, #T_46c93_row12_col7, #T_46c93_row13_col0, #T_46c93_row13_col1, #T_46c93_row13_col2, #T_46c93_row13_col3, #T_46c93_row13_col4, #T_46c93_row13_col5, #T_46c93_row13_col6, #T_46c93_row13_col7, #T_46c93_row14_col0, #T_46c93_row14_col1, #T_46c93_row14_col2, #T_46c93_row14_col3, #T_46c93_row14_col4, #T_46c93_row14_col5, #T_46c93_row14_col6, #T_46c93_row14_col7 {
#   text-align: left;
# }
# #T_46c93_row0_col1, #T_46c93_row0_col6, #T_46c93_row0_col7, #T_46c93_row1_col2, #T_46c93_row1_col4, #T_46c93_row12_col3, #T_46c93_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_46c93_row0_col8, #T_46c93_row1_col8, #T_46c93_row2_col8, #T_46c93_row4_col8, #T_46c93_row5_col8, #T_46c93_row6_col8, #T_46c93_row7_col8, #T_46c93_row8_col8, #T_46c93_row9_col8, #T_46c93_row10_col8, #T_46c93_row11_col8, #T_46c93_row12_col8, #T_46c93_row13_col8, #T_46c93_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_46c93_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_46c93_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46c93_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_46c93_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_46c93_row0_col1" class="data row0 col1" >0.7959</td>
#       <td id="T_46c93_row0_col2" class="data row0 col2" >0.8377</td>
#       <td id="T_46c93_row0_col3" class="data row0 col3" >0.5448</td>
#       <td id="T_46c93_row0_col4" class="data row0 col4" >0.6493</td>
#       <td id="T_46c93_row0_col5" class="data row0 col5" >0.5919</td>
#       <td id="T_46c93_row0_col6" class="data row0 col6" >0.4574</td>
#       <td id="T_46c93_row0_col7" class="data row0 col7" >0.4609</td>
#       <td id="T_46c93_row0_col8" class="data row0 col8" >0.2330</td>
#     </tr>
#     <tr>
#       <th id="T_46c93_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_46c93_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_46c93_row1_col1" class="data row1 col1" >0.7935</td>
#       <td id="T_46c93_row1_col2" class="data row1 col2" >0.8396</td>
#       <td id="T_46c93_row1_col3" class="data row1 col3" >0.5097</td>
#       <td id="T_46c93_row1_col4" class="data row1 col4" >0.6568</td>
#       <td id="T_46c93_row1_col5" class="data row1 col5" >0.5726</td>
#       <td id="T_46c93_row1_col6" class="data row1 col6" >0.4395</td>
#       <td id="T_46c93_row1_col7" class="data row1 col7" >0.4465</td>
#       <td id="T_46c93_row1_col8" class="data row1 col8" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_46c93_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_46c93_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_46c93_row2_col1" class="data row2 col1" >0.7921</td>
#       <td id="T_46c93_row2_col2" class="data row2 col2" >0.8282</td>
#       <td id="T_46c93_row2_col3" class="data row2 col3" >0.5537</td>
#       <td id="T_46c93_row2_col4" class="data row2 col4" >0.6376</td>
#       <td id="T_46c93_row2_col5" class="data row2 col5" >0.5915</td>
#       <td id="T_46c93_row2_col6" class="data row2 col6" >0.4532</td>
#       <td id="T_46c93_row2_col7" class="data row2 col7" >0.4560</td>
#       <td id="T_46c93_row2_col8" class="data row2 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_46c93_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_46c93_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_46c93_row3_col1" class="data row3 col1" >0.7876</td>
#       <td id="T_46c93_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_46c93_row3_col3" class="data row3 col3" >0.4799</td>
#       <td id="T_46c93_row3_col4" class="data row3 col4" >0.6488</td>
#       <td id="T_46c93_row3_col5" class="data row3 col5" >0.5507</td>
#       <td id="T_46c93_row3_col6" class="data row3 col6" >0.4159</td>
#       <td id="T_46c93_row3_col7" class="data row3 col7" >0.4246</td>
#       <td id="T_46c93_row3_col8" class="data row3 col8" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_46c93_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_46c93_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_46c93_row4_col1" class="data row4 col1" >0.7876</td>
#       <td id="T_46c93_row4_col2" class="data row4 col2" >0.8360</td>
#       <td id="T_46c93_row4_col3" class="data row4 col3" >0.5142</td>
#       <td id="T_46c93_row4_col4" class="data row4 col4" >0.6356</td>
#       <td id="T_46c93_row4_col5" class="data row4 col5" >0.5671</td>
#       <td id="T_46c93_row4_col6" class="data row4 col6" >0.4289</td>
#       <td id="T_46c93_row4_col7" class="data row4 col7" >0.4338</td>
#       <td id="T_46c93_row4_col8" class="data row4 col8" >1.6460</td>
#     </tr>
#     <tr>
#       <th id="T_46c93_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_46c93_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_46c93_row5_col1" class="data row5 col1" >0.7860</td>
#       <td id="T_46c93_row5_col2" class="data row5 col2" >0.8352</td>
#       <td id="T_46c93_row5_col3" class="data row5 col3" >0.5157</td>
#       <td id="T_46c93_row5_col4" class="data row5 col4" >0.6332</td>
#       <td id="T_46c93_row5_col5" class="data row5 col5" >0.5674</td>
#       <td id="T_46c93_row5_col6" class="data row5 col6" >0.4273</td>
#       <td id="T_46c93_row5_col7" class="data row5 col7" >0.4319</td>
#       <td id="T_46c93_row5_col8" class="data row5

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1257, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 7)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
#             tenure PhoneService        Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4          Yes  Month-to-month  Mailed check            74.4
#
#             TotalCharges Churn Label   Score
# customerID
# 8361-LTMKD         306.6   Yes    No  0.6053

# %% [markdown]
# # 3. Save Model

# %% [markdown]
# The experiment contains two models.  One model, Gradient Boosting Classifier, with the prepared dataset 'churnNum'.  The second model, Logistic Regression, was created off the original dataset 'churn_data'.

# %%
save_model(best_model, 'lr')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=1257,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False)]],
#           verbose=False),
#  'lr.pkl')

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# def load_data(filepath):
#     """
#     Loads diabetes data into a DataFrame from a string filepath.
#     """
#     df = pd.read_csv(filepath)
#     return df
#
#
# def make_predictions(df):
#     """
#     Uses the pycaret best model to make predictions on data in the df dataframe.
#     """
#     model = load_model('lr')
#     predictions = predict_model(model, data=df)
#     predictions.rename({'Label': 'Churn_prediction'}, axis=1, inplace=True)
#     predictions['Churn_prediction'].replace({1: 'Churn', 0: 'No Churn'},
#                                             inplace=True)
#     return predictions['Churn_prediction']
#
#
# if __name__ == "__main__":
#     df = load_data('new_churn_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %%
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
# predictions:
# 0     No
# 1     No
# 2     No
# 3     No
# 4    Yes
# Name: Churn_prediction, dtype: object
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.3517e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.31854e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.33929e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.34528e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.36888e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.35719e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.3579e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.35614e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.42159e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/g7/anaconda3/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.36832e-11): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /home/g7/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %% [markdown]
# # Summary

# %% [markdown]
# Original automl work in JupyterLab had errors. When switching to Notebook the problem seemed to resolve. Experimentation with 2 datasets resulted in the two differing models.  Best model for prepared numeric data was Gradient Boosting Classifier.  Logistic Regression perfomed the best on unprepared data. Both models were saved as 'lr' and 'gbc' pickle files.  The python automation script can be adjusted accordingly to use either.
